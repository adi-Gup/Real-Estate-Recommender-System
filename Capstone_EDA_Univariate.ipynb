# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)

# %%
df = pd.read_csv('/content/gurgaon_properties_cleaned_v2.csv')

# %%
df.head()
# Out:
#   property_type                  society      sector  price  price_per_sqft  \
# 0          flat       ambience creacions   sector 22   1.65         11956.0
# 1          flat  shree vardhman victoria   sector 70   1.66         14254.0
# 2          flat               bptp terra  sector 37d   1.60          7302.0
# 3         house              independent   sector 11   1.35          3857.0
# 4          flat  shree vardhman victoria   sector 70   1.23          9111.0
#
#      area                                       areaWithType  bedRoom  \
# 0  1380.0  Super Built up area 1380(128.21 sq.m.)Built Up...        2
# 1  1165.0  Super Built up area 1950(181.16 sq.m.)Carpet a...        3
# 2  2191.0  Super Built up area 2191(203.55 sq.m.)Built Up...        4
# 3  3500.0                       Plot area 3500(325.16 sq.m.)       10
# 4  1350.0             Super Built up area 1350(125.42 sq.m.)        2
#
#    bathroom balcony  floorNum      facing   agePossession  \
# ...

# %%
df.shape
# Out:
# (3803, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3803 entries, 0 to 3802
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   property_type        3803 non-null   object
#  1   society              3802 non-null   object
#  2   sector               3803 non-null   object
#  3   price                3785 non-null   float64
#  4   price_per_sqft       3785 non-null   float64
#  5   area                 3785 non-null   float64
#  6   areaWithType         3803 non-null   object
#  7   bedRoom              3803 non-null   int64
#  8   bathroom             3803 non-null   int64
#  9   balcony              3803 non-null   object
#  10  floorNum             3784 non-null   float64
#  11  facing               2698 non-null   object
#  12  agePossession        3803 non-null   object
#  13  super_built_up_area  1915 non-null   float64
#  14  built_up_area        1733 non-null   float64
# ...

# %%
df.duplicated().sum()
# Out:
# 126

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (3677, 23)

# %% [markdown]
# #1 Property Type

# %%
df['property_type'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='property_type'>

# %%
df['property_type'].value_counts()/df.shape[0]*100
# Out:
# property_type
# flat     76.638564
# house    23.361436
# Name: count, dtype: float64

# %%
df['property_type'].isna().sum()
# Out:
# 0

# %% [markdown]
# **Observation**
# 1.   There are around 76% flats and 24% houses.
# 2.   There are no null values in this column.

# %% [markdown]
# #2 Society

# %%
df['society'].value_counts()
# Out:
# society
# independent                                          486
# tulip violet                                          75
# ss the leaf                                           73
# shapoorji pallonji joyville gurugram                  42
# dlf new town heights                                  42
# signature global park                                 35
# shree vardhman victoria                               34
# emaar mgf emerald floors premier                      32
# smart world orchard                                   32
# paras dews                                            31
# dlf the ultima                                        31
# m3m woodshire                                         30
# dlf regal gardens                                     30
# shree vardhman flora                                  29
# la vida by tata housing                               28
# smart world gems                                      28
# ...

# %%
df[df['society'] != 'independent']['society'].value_counts(normalize=True).cumsum().head(75)
# Out:
# society
# tulip violet                            0.023511
# ss the leaf                             0.046395
# dlf new town heights                    0.059561
# shapoorji pallonji joyville gurugram    0.072727
# signature global park                   0.083699
# shree vardhman victoria                 0.094357
# emaar mgf emerald floors premier        0.104389
# smart world orchard                     0.114420
# paras dews                              0.124138
# dlf the ultima                          0.133856
# dlf regal gardens                       0.143260
# m3m woodshire                           0.152665
# shree vardhman flora                    0.161755
# la vida by tata housing                 0.170533
# smart world gems                        0.179310
# signature global solera                 0.187774
# godrej nature plus                      0.196238
# bptp terra                              0.204075
# experion the heartsong                  0.211599
# ...

# %%
society_counts = df['society'].value_counts()

frequency_counts = {'very high (>100)': (society_counts > 100).sum(),
    "High (50-100)": ((society_counts >= 50) & (society_counts <= 100)).sum(),
    "Average (10-49)": ((society_counts >= 10) & (society_counts < 50)).sum(),
    "Low (2-9)": ((society_counts > 1) & (society_counts < 10)).sum(),
    "Very Low (1)": (society_counts == 1).sum()}
frequency_counts
# Out:
# {'very high (>100)': 1,
#  'High (50-100)': 2,
#  'Average (10-49)': 92,
#  'Low (2-9)': 273,
#  'Very Low (1)': 308}

# %%
df['society'].isna().sum()
# Out:
# 1

# %%
df[df['society'].isna()]
# Out:
#      property_type society     sector  price  price_per_sqft    area  \
# 3683          flat     NaN  sector 78    0.6          3692.0  1625.0
#
#                             areaWithType  bedRoom  bathroom balcony  floorNum  \
# 3683  Built Up area: 1625 (150.97 sq.m.)        2         2       0       NaN
#
#      facing       agePossession  super_built_up_area  built_up_area  \
# 3683    NaN  Under Construction                  NaN         1625.0
#
#       carpet_area  study room  servant room  store room  pooja room  others  \
# 3683          NaN           0             0           0           0       0
#
#       furnishing_type  luxury_score
# 3683                1             0

# %%
df[df['society']!= 'independent']['society'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='society'>

# %%
df['society'].value_counts().shape
# Out:
# (676,)

# %% [markdown]
# **Observations**
#
# 1. Around 13% properties comes under independent tag.
# There are 675 societies.
#
# 2. The top 75 societies have 50 percent of the preperties and the rest 50 percent of the properties come under the remaining 600 societies.
#
#   1. Very High (>100): Only 1 society has more than 100 listings.
#   2. High (50-100): 2 societies have between 50 to 100 listings.
#   3.Average (10-49): 92 societies fall in this range with 10 to 49 listings each.
#   4. Low (2-9): 273 societies have between 2 to 9 listings.
#   5. Very Low (1): A significant number, 308 societies, have only 1 listing.
#
# 3. 1 missing value

# %% [markdown]
# # Sector

# %%
df['sector'].value_counts()
# Out:
# sector
# sohna road                    154
# sector 85                     107
# sector 102                    107
# sector 92                     100
# sector 69                      93
# sector 90                      89
# sector 81                      87
# sector 65                      86
# sector 109                     86
# sector 79                      76
# sector 33                      69
# sector 104                     69
# sector 83                      68
# sector 43                      65
# sector 50                      64
# sector 86                      64
# sector 37d                     63
# sector 95                      62
# sector 2                       61
# sector 107                     60
# sector 108                     59
# sector 89                      57
# sector 56                      56
# sector 48                      55
# sector 70a                     54
# sector 26                      50
# sector 37c                     50
# ...

# %%
df['sector'].value_counts().shape
# Out:
# (115,)

# %%
df[df['sector'] == 'new'].index
# Out:
# Index([117, 1398, 1734, 3643], dtype='int64')

# %%
df.loc[3643,'sector'] = 'sector 37'
df.loc[117,'sector'] = 'sector 90'
df.loc[1398,'sector'] = 'sector 76'
df.loc[1734,'sector'] = 'sector 92'

# %%
df[df['sector'] == 'sector 3 phase 2'].index
# Out:
# Index([22, 327, 486, 668, 1902, 3093, 3097, 3098], dtype='int64')

# %%
df.loc[[22, 327, 486, 668, 1902, 3093, 3097, 3098],'sector'] = 'sector 3'

# %%
df[df['sector'] == 'dwarka expressway']
# Out:
#      property_type                     society             sector  price  \
# 613           flat                  hero homes  dwarka expressway   1.60
# 894           flat        ansals highland park  dwarka expressway   1.20
# 1548          flat             ramprastha city  dwarka expressway   1.30
# 1838          flat          experion heartsong  dwarka expressway   1.08
# 2023          flat             ramprastha city  dwarka expressway   1.30
# 2494          flat                  the cocoon  dwarka expressway   2.00
# 2745         house  rattan vihar rajendra park  dwarka expressway   0.85
# 2938          flat             smart world one  dwarka expressway   1.65
#
#       price_per_sqft    area                            areaWithType  bedRoom  \
# 613           7825.0  2045.0  Super Built up area 1689(156.91 sq.m.)        3
# 894           6185.0  1940.0      Built Up area: 1940 (180.23 sq.m.)        3
# ...

# %%
df[df['sector'] == 'dwarka expressway'].index
# Out:
# Index([613, 894, 1548, 1838, 2023, 2494, 2745, 2938], dtype='int64')

# %%
df.loc[613, 'sector'] = 'sector 104'
df.loc[894, 'sector'] = 'sector 103'
df.loc[1548, 'sector'] = 'sector 37D'
df.loc[1838, 'sector'] = 'sector 108'
df.loc[2023, 'sector'] = 'sector 37D'
df.loc[2494, 'sector'] = 'sector 109'
df.loc[2745, 'sector'] = 'sector 105'
df.loc[2938, 'sector'] = 'sector 113'

# %%
df[df['sector'] == 'sector 3 phase 3 extension']
# Out:
#      property_type                          society  \
# 258          house                      independent
# 442          house                      independent
# 783          house      ashok vihar phase 3 gurgaon
# 1074         house                      independent
# 1788         house                      independent
# 1946         house                      independent
# 2182         house                      independent
# 2615          flat                  vidya apartment
# 2659         house                      independent
# 3132          flat                  pooja apartment
# 3331         house  ashok vihar phase iii extension
#
#                           sector  price  price_per_sqft    area  \
# 258   sector 3 phase 3 extension   1.00          6667.0  1500.0
# 442   sector 3 phase 3 extension   1.50          5000.0  3000.0
# 783   sector 3 phase 3 extension   0.95          8878.0  1070.0
# 1074  sector 3 phase 3 extension   0.85          8500.0  1000.0
# ...

# %%
df.loc[[258, 442, 783, 1074, 1788, 1946, 2182, 2615, 2659, 3132, 3331],'sector'] = 'sector 3'

# %%
df[df['sector'] == 'sohna road road']
# Out:
#      property_type                     society           sector  price  \
# 59           house                 independent  sohna road road   5.50
# 366          house                 independent  sohna road road   0.49
# 427          house                 independent  sohna road road   0.50
# 545          house                 independent  sohna road road   1.20
# 1910         house                 independent  sohna road road   6.25
# 2078          flat  central park flower valley  sohna road road   1.65
# 2125          flat               micasa sec 68  sohna road road   1.50
# 2250         house          cloudnine cottages  sohna road road   5.50
# 2510         house                  sneh vihar  sohna road road   1.35
# 2838         house                 independent  sohna road road   0.95
# 3326         house                   prem kunj  sohna road road   0.50
# 3350          flat                   bhemerlei  sohna road road   0.69
#
#       price_per_sqft     area  \
# ...

# %%
df.loc[2078,'sector'] = 'sector 32'
df.loc[2125,'sector'] = 'sector 68'
df.loc[2250,'sector'] = 'sector 68'

# %%
df[df['sector'] == 'manesar']['society']
# Out:
# 36                    dlf express greens
# 107     hsiidc sidco shivalik apartments
# 151                 hsiidc sidco aravali
# 269                         deepak minda
# 320        denso haryana housing society
# 406                 hsiidc sidco aravali
# 705                   dlf express greens
# 717                   dlf express greens
# 813                 hsiidc sidco aravali
# 886          sbr minda sec 1 imt manesar
# 1010    hsiidc sidco shivalik apartments
# 1149                    imt view society
# 1183                       eden landmark
# 1434          sonata group housing gh 24
# 1482                professional society
# 1679            the crew bos chs manesar
# 1879                        deepak minda
# 1908          dnha group housing society
# 1920                       sbr apartment
# 2110         sbr minda sec-1 imt manesar
# 2263                         independent
# 2303    hsiidc sidco shivalik apartments
# 2583                        deepak minda
# ...

# %%
df['society'] = df['society'].str.strip()

# %%
df[df['sector'] == 'manesar']['society'].index
# Out:
# Index([  36,  107,  151,  269,  320,  406,  705,  717,  813,  886, 1010, 1149,
#        1183, 1434, 1482, 1679, 1879, 1908, 1920, 2110, 2263, 2303, 2583, 2780,
#        2799, 2845, 2857, 2889, 3337, 3397, 3589, 3656, 3736],
#       dtype='int64')

# %%
df.loc[[  36,  107,  151,  269,  320,  406,  705,  717,  813,  886, 1010, 1149,
       1183, 1434, 1482, 1679, 1879, 1908, 1920, 2110, 2263, 2303, 2583, 2780,
       2799, 2845, 2857, 2889, 3337, 3397, 3589, 3656, 3736],'sector'] = 'sector 1'

# %%
df[df['sector'] == 'gwal pahari'][['society','sector']]
# Out:
#                      society       sector
# 24    krrish provence estate  gwal pahari
# 310   krrish provence estate  gwal pahari
# 562           paras quartier  gwal pahari
# 623       valley view estate  gwal pahari
# 729           paras quartier  gwal pahari
# 846    suncity vatsal valley  gwal pahari
# 928    suncity vatsal valley  gwal pahari
# 1059          paras quartier  gwal pahari
# 1447                 bsf chs  gwal pahari
# 1665   suncity vatsal valley  gwal pahari
# 1721                     nul  gwal pahari
# 1877      valley view estate  gwal pahari
# 1940                       .  gwal pahari
# 1960   suncity vatsal valley  gwal pahari
# 2272   suncity vatsal valley  gwal pahari
# 2637   suncity vatsal valley  gwal pahari
# 3114      valley view estate  gwal pahari
# 3318  krrish provence estate  gwal pahari

# %%
df[df['sector'] == 'sohna road road'].index
# Out:
# Index([59, 366, 427, 545, 1910, 2510, 2838, 3326, 3350], dtype='int64')

# %%
df.loc[[59, 366, 427, 545, 1910, 2510, 2838, 3326, 3350],'sector'] = 'sohna road'

# %%
df['sector'].value_counts().shape
# Out:
# (111,)
